# %% [markdown]
# <a href="https://colab.research.google.com/github/nthammadi-uncc/StarbucksPromotionAnalysis/blob/main/Offer_Accepted_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load Necessary Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Loading in Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nthammadi-uncc/StarbucksPromotionAnalysis/main/data/clean/offer_completed.csv')
df
# Out:
#        Unnamed: 0                          offer_id  time  reward  difficulty  \
# 0               0  2906b810c7d4411798c6938adc9daaa5     0       2          10
# 1               1  fafdcd668e3743c1bb461111dcafc2a4     0       2          10
# 2               2  9b98b8c7a33c4b65b9aebfe6a799e6d9     0       5           5
# 3               3  ae264e3637204a6fb9bb56bc8210ddfd     0      10          10
# 4               4  4d5c57ea9a6940dd891ad53e9dbe8da0     0      10          10
# ...           ...                               ...   ...     ...         ...
# 33574       33574  2298d6c36e964ae4a3e7e9706d1fb8c2   714       3           7
# 33575       33575  2298d6c36e964ae4a3e7e9706d1fb8c2   714       3           7
# 33576       33576  fafdcd668e3743c1bb461111dcafc2a4   714       2          10
# 33577       33577  fafdcd668e3743c1bb461111dcafc2a4   714       2          10
# 33578       33578  fafdcd668e3743c1bb461111dcafc2a4   714       2          10
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# offer_id             object
# time                  int64
# reward                int64
# difficulty            int64
# duration              int64
# offer_type           object
# web_channel           int64
# mobile_channel        int64
# social_channel        int64
# person_id            object
# gender               object
# age                 float64
# became_member_on     object
# income              float64
# dtype: object

# %%
df.describe()
# Out:
#          Unnamed: 0          time        reward    difficulty      duration  \
# count  33579.000000  33579.000000  33579.000000  33579.000000  33579.000000
# mean   16789.000000    401.052801      4.904137      9.269841      7.326305
# std     9693.566681    192.352614      2.886647      4.180227      1.773103
# min        0.000000      0.000000      2.000000      5.000000      5.000000
# 25%     8394.500000    240.000000      2.000000      5.000000      7.000000
# 50%    16789.000000    432.000000      5.000000     10.000000      7.000000
# 75%    25183.500000    564.000000      5.000000     10.000000     10.000000
# max    33578.000000    714.000000     10.000000     20.000000     10.000000
#
#         web_channel  mobile_channel  social_channel           age  \
# count  33579.000000    33579.000000    33579.000000  32444.000000
# mean       0.890169        0.898151        0.648858     55.826624
# std        0.312683        0.302455        0.477334     16.809418
# ...

# %% [markdown]
# (Make conclusions about mean/others statistics from above graph)

# %%
import matplotlib.pyplot as plt
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ffac4c75f10>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df[['time', 'reward', 'difficulty', 'duration', 'web_channel', 'mobile_channel', 'social_channel', 'age', 'income']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ffac41a4690>,
# ...
#       dtype=object)

# %%
import seaborn as sns
plt.figure(figsize=(9,6))
sns.heatmap(df.corr(),annot=True,cmap='cubehelix_r')
plt.show()
