# %% [markdown]
# <a href="https://colab.research.google.com/github/nthammadi-uncc/StarbucksPromotionAnalysis/blob/main/Offer_Received_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load Necessary Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Loading in Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nthammadi-uncc/StarbucksPromotionAnalysis/main/data/clean/offer_received.csv')
df
# Out:
#        Unnamed: 0                          offer_id  time  reward  difficulty  \
# 0               0  9b98b8c7a33c4b65b9aebfe6a799e6d9     0       5           5
# 1               1  0b1e1539f2cc45b7b9fa7c272da2e1d7     0       5          20
# 2               2  2906b810c7d4411798c6938adc9daaa5     0       2          10
# 3               3  fafdcd668e3743c1bb461111dcafc2a4     0       2          10
# 4               4  4d5c57ea9a6940dd891ad53e9dbe8da0     0      10          10
# ...           ...                               ...   ...     ...         ...
# 76272       76272  ae264e3637204a6fb9bb56bc8210ddfd   576      10          10
# 76273       76273  2906b810c7d4411798c6938adc9daaa5   576       2          10
# 76274       76274  2298d6c36e964ae4a3e7e9706d1fb8c2   576       3           7
# 76275       76275  ae264e3637204a6fb9bb56bc8210ddfd   576      10          10
# 76276       76276  3f207df678b143eea3cee63160fa8bed   576       0           0
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# offer_id             object
# time                  int64
# reward                int64
# difficulty            int64
# duration              int64
# offer_type           object
# web_channel           int64
# mobile_channel        int64
# social_channel        int64
# person_id            object
# gender               object
# age                 float64
# became_member_on     object
# income              float64
# dtype: object

# %%
df.describe()
# Out:
#          Unnamed: 0          time        reward    difficulty      duration  \
# count  76277.000000  76277.000000  76277.000000  76277.000000  76277.000000
# mean   38138.000000    332.579519      4.201607      7.707723      6.503704
# std    22019.417579    196.489548      3.398888      5.538203      2.201544
# min        0.000000      0.000000      0.000000      0.000000      3.000000
# 25%    19069.000000    168.000000      2.000000      5.000000      5.000000
# 50%    38138.000000    408.000000      5.000000     10.000000      7.000000
# 75%    57207.000000    504.000000      5.000000     10.000000      7.000000
# max    76276.000000    576.000000     10.000000     20.000000     10.000000
#
#         web_channel  mobile_channel  social_channel           age  \
# count  76277.000000    76277.000000    76277.000000  66501.000000
# mean       0.799730        0.899472        0.598909     54.369258
# std        0.400205        0.300705        0.490123     17.395430
# ...

# %% [markdown]
# (Make conclusions about mean/others statistics from above graph)

# %%
import matplotlib.pyplot as plt
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe0b434f7d0>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df[['time', 'reward', 'difficulty', 'duration', 'web_channel', 'mobile_channel', 'social_channel', 'age', 'income']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe0b392c5d0>,
# ...
#       dtype=object)

# %%
import seaborn as sns
plt.figure(figsize=(9,6))
sns.heatmap(df.corr(),annot=True,cmap='cubehelix_r')
plt.show()
