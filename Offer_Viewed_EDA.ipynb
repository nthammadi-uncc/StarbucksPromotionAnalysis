# %% [markdown]
# <a href="https://colab.research.google.com/github/nthammadi-uncc/StarbucksPromotionAnalysis/blob/main/Offer_Viewed_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load Necessary Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Loading in Data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nthammadi-uncc/StarbucksPromotionAnalysis/main/data/clean/offer_viewed.csv')
df
# Out:
#        Unnamed: 0                          offer_id  time  reward  difficulty  \
# 0               0  f19421c1d4aa40978ebb69ca19b0e20d     0       5           5
# 1               1  5a8bc65990b245e5a138643cd4eb9837     0       0           0
# 2               2  4d5c57ea9a6940dd891ad53e9dbe8da0     0      10          10
# 3               3  ae264e3637204a6fb9bb56bc8210ddfd     0      10          10
# 4               4  5a8bc65990b245e5a138643cd4eb9837     0       0           0
# ...           ...                               ...   ...     ...         ...
# 57720       57720  5a8bc65990b245e5a138643cd4eb9837   714       0           0
# 57721       57721  3f207df678b143eea3cee63160fa8bed   714       0           0
# 57722       57722  5a8bc65990b245e5a138643cd4eb9837   714       0           0
# 57723       57723  3f207df678b143eea3cee63160fa8bed   714       0           0
# 57724       57724  0b1e1539f2cc45b7b9fa7c272da2e1d7   714       5          20
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0            int64
# offer_id             object
# time                  int64
# reward                int64
# difficulty            int64
# duration              int64
# offer_type           object
# web_channel           int64
# mobile_channel        int64
# social_channel        int64
# person_id            object
# gender               object
# age                 float64
# became_member_on     object
# income              float64
# dtype: object

# %%
df.describe()
# Out:
#          Unnamed: 0          time        reward    difficulty      duration  \
# count  57725.000000  57725.000000  57725.000000  57725.000000  57725.000000
# mean   28862.000000    354.290515      4.426696      7.213235      6.335920
# std    16663.916481    199.317684      3.567132      4.659072      2.150644
# min        0.000000      0.000000      0.000000      0.000000      3.000000
# 25%    14431.000000    180.000000      2.000000      5.000000      5.000000
# 50%    28862.000000    408.000000      3.000000      7.000000      7.000000
# 75%    43293.000000    516.000000      5.000000     10.000000      7.000000
# max    57724.000000    714.000000     10.000000     20.000000     10.000000
#
#         web_channel  mobile_channel  social_channel           age  \
# count  57725.000000    57725.000000    57725.000000  49860.000000
# mean       0.767813        0.953867        0.738484     54.644645
# std        0.422231        0.209774        0.439464     17.142283
# ...

# %% [markdown]
# (Make conclusions about mean/others statistics from above graph)

# %%
import matplotlib.pyplot as plt
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1be077be90>,
# ...
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df[['time', 'reward', 'difficulty', 'duration', 'web_channel', 'mobile_channel', 'social_channel', 'age', 'income']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1be024cd10>,
# ...
#       dtype=object)

# %%
import seaborn as sns
plt.figure(figsize=(9,6))
sns.heatmap(df.corr(),annot=True,cmap='cubehelix_r')
plt.show()
