# %% [markdown]
# <a href="https://colab.research.google.com/github/nthammadi-uncc/StarbucksPromotionAnalysis/blob/main/Jupyter%20Notebooks/SB_Exploratory_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Load necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %% [markdown]
# ### Read data files

# %%
#read the csv files and convert into dataframe
parent_url='https://raw.githubusercontent.com/nthammadi-uncc/StarbucksPromotionAnalysis/main/data/not%20in%20use/'
offer_received_url=parent_url+'offer_received.csv'
offer_viewed_url=parent_url+'offer_viewed.csv'
offer_completed_url=parent_url+'offer_completed.csv'

offer_received_df=pd.read_csv(offer_received_url)
offer_received_df = offer_received_df.iloc[: , 1:]
offer_viewed_df=pd.read_csv(offer_viewed_url)
offer_viewed_df = offer_viewed_df.iloc[: , 1:]
offer_completed_df=pd.read_csv(offer_completed_url)
offer_completed_df = offer_completed_df.iloc[: , 1:]

offers_df=pd.read_csv('https://raw.githubusercontent.com/nthammadi-uncc/StarbucksPromotionAnalysis/main/data/clean/final_consolidated_offers.csv')
offers_df = offers_df.iloc[: , 1:]

# %% [markdown]
# ### Plots

# %% [markdown]
# ##### All Offers

# %%
offers_df.dtypes
# Out:
# person_id              object
# gender                 object
# age                   float64
# became_member_on       object
# income                float64
# offer_id               object
# reward                  int64
# difficulty              int64
# duration                int64
# offer_type             object
# web_channel             int64
# mobile_channel          int64
# social_channel          int64
# duration_start_day      int64
# duration_end_day        int64
# week                    int64
# r_min_time              int64
# r_max_time              int64
# r_record_counts         int64
# r_min_day               int64
# r_max_day               int64
# v_min_time            float64
# v_max_time            float64
# v_record_counts       float64
# c_min_time            float64
# c_max_time            float64
# c_record_counts       float64
# t_min_time            float64
# t_max_time            float64
# t_record_counts       float64
# transaction_amount    float64
# ...

# %%
offers_df.describe()
# Out:
#                 age         income        reward    difficulty      duration  \
# count  64841.000000   64841.000000  74356.000000  74356.000000  74356.000000
# mean      54.387563   65392.267238      4.204032      7.709721      6.504088
# std       17.392266   21637.543943      3.399897      5.536465      2.201135
# min       18.000000   30000.000000      0.000000      0.000000      3.000000
# 25%       42.000000   49000.000000      2.000000      5.000000      5.000000
# 50%       55.000000   64000.000000      5.000000     10.000000      7.000000
# 75%       66.000000   80000.000000      5.000000     10.000000      7.000000
# max      101.000000  120000.000000     10.000000     20.000000     10.000000
#
#         web_channel  mobile_channel  social_channel  duration_start_day  \
# count  74356.000000    74356.000000    74356.000000        74356.000000
# mean       0.799788        0.899524        0.599064           14.687046
# ...

# %%
offers_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f65cfbc68d0>,
# ...
#       dtype=object)

# %%
scatter_matrix(offers_df[['reward', 'difficulty', 'duration', 'web_channel', 'mobile_channel', 'social_channel', 'age', 'income', 'r_min_time', 'r_max_time', 'v_min_time', 'v_max_time', 'c_min_time', 'c_max_time', 't_min_time', 't_max_time', 'transaction_amount', 'successful_offer']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f65cf0d4210>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(offers_df.corr(),annot=True,cmap='cubehelix_r')
plt.show()

# %% [markdown]
# ##### Offers Received

# %%
offer_received_df.dtypes
# Out:
# offer_id             object
# time                  int64
# reward                int64
# difficulty            int64
# duration              int64
# offer_type           object
# web_channel           int64
# mobile_channel        int64
# social_channel        int64
# person_id            object
# gender               object
# age                 float64
# became_member_on     object
# income              float64
# dtype: object

# %%
offer_received_df.describe()
# Out:
#                time        reward    difficulty      duration   web_channel  \
# count  76277.000000  76277.000000  76277.000000  76277.000000  76277.000000
# mean     332.579519      4.201607      7.707723      6.503704      0.799730
# std      196.489548      3.398888      5.538203      2.201544      0.400205
# min        0.000000      0.000000      0.000000      3.000000      0.000000
# 25%      168.000000      2.000000      5.000000      5.000000      1.000000
# 50%      408.000000      5.000000     10.000000      7.000000      1.000000
# 75%      504.000000      5.000000     10.000000      7.000000      1.000000
# max      576.000000     10.000000     20.000000     10.000000      1.000000
#
#        mobile_channel  social_channel           age         income
# count    76277.000000    76277.000000  66501.000000   66501.000000
# mean         0.899472        0.598909     54.369258   65371.618472
# std          0.300705        0.490123     17.395430   21623.288473
# ...

# %% [markdown]
# (Make conclusions about mean/others statistics from above graph)

# %%
offer_received_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f65c5f80ed0>,
# ...
#       dtype=object)

# %%
scatter_matrix(offer_received_df[['time', 'reward', 'difficulty', 'duration', 'web_channel', 'mobile_channel', 'social_channel', 'age', 'income']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f65c431f190>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(9,6))
sns.heatmap(offer_received_df.corr(),annot=True,cmap='cubehelix_r')
plt.show()

# %% [markdown]
# ##### Offers Viewed

# %%
offer_viewed_df.dtypes
# Out:
# offer_id             object
# time                  int64
# reward                int64
# difficulty            int64
# duration              int64
# offer_type           object
# web_channel           int64
# mobile_channel        int64
# social_channel        int64
# person_id            object
# gender               object
# age                 float64
# became_member_on     object
# income              float64
# dtype: object

# %%
offer_viewed_df.describe()
# Out:
#                time        reward    difficulty      duration   web_channel  \
# count  57725.000000  57725.000000  57725.000000  57725.000000  57725.000000
# mean     354.290515      4.426696      7.213235      6.335920      0.767813
# std      199.317684      3.567132      4.659072      2.150644      0.422231
# min        0.000000      0.000000      0.000000      3.000000      0.000000
# 25%      180.000000      2.000000      5.000000      5.000000      1.000000
# 50%      408.000000      3.000000      7.000000      7.000000      1.000000
# 75%      516.000000      5.000000     10.000000      7.000000      1.000000
# max      714.000000     10.000000     20.000000     10.000000      1.000000
#
#        mobile_channel  social_channel           age         income
# count    57725.000000    57725.000000  49860.000000   49860.000000
# mean         0.953867        0.738484     54.644645   65841.596470
# std          0.209774        0.439464     17.142283   21075.168266
# ...

# %% [markdown]
# (Make conclusions about mean/others statistics from above graph)

# %%
offer_viewed_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f65c30de690>,
# ...
#       dtype=object)

# %%
scatter_matrix(offer_viewed_df[['time', 'reward', 'difficulty', 'duration', 'web_channel', 'mobile_channel', 'social_channel', 'age', 'income']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f65c2d7eb90>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(9,6))
sns.heatmap(offer_viewed_df.corr(),annot=True,cmap='cubehelix_r')
plt.show()

# %% [markdown]
# ##### Offers Completed

# %%
offer_completed_df.dtypes
# Out:
# offer_id             object
# time                  int64
# reward                int64
# difficulty            int64
# duration              int64
# offer_type           object
# web_channel           int64
# mobile_channel        int64
# social_channel        int64
# person_id            object
# gender               object
# age                 float64
# became_member_on     object
# income              float64
# dtype: object

# %%
offer_completed_df.describe()
# Out:
#                time        reward    difficulty      duration   web_channel  \
# count  33579.000000  33579.000000  33579.000000  33579.000000  33579.000000
# mean     401.052801      4.904137      9.269841      7.326305      0.890169
# std      192.352614      2.886647      4.180227      1.773103      0.312683
# min        0.000000      2.000000      5.000000      5.000000      0.000000
# 25%      240.000000      2.000000      5.000000      7.000000      1.000000
# 50%      432.000000      5.000000     10.000000      7.000000      1.000000
# 75%      564.000000      5.000000     10.000000     10.000000      1.000000
# max      714.000000     10.000000     20.000000     10.000000      1.000000
#
#        mobile_channel  social_channel           age         income
# count    33579.000000    33579.000000  32444.000000   32444.000000
# mean         0.898151        0.648858     55.826624   69430.803847
# std          0.302455        0.477334     16.809418   21604.250324
# ...

# %% [markdown]
# (Make conclusions about mean/others statistics from above graph)

# %%
offer_completed_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f65c15bae90>,
# ...
#       dtype=object)

# %%
scatter_matrix(offer_completed_df[['time', 'reward', 'difficulty', 'duration', 'web_channel', 'mobile_channel', 'social_channel', 'age', 'income']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f65c11ace50>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(9,6))
sns.heatmap(offer_completed_df.corr(),annot=True,cmap='cubehelix_r')
plt.show()
